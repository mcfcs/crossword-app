# %%
import pandas as pd

df = pd.read_csv("tagalog_bugtong.csv")
df
# Out:
#                   Word                                               Clue
# 0                SAPAT     Di dapat na kulangin, di rin dapat pasobrahin.
# 1               SANGKO  Kung may ditche at diko sa sambahayan, kapartn...
# 2               SARONG  Barong itinatapis lamang, maaaring gawing porm...
# 3                SINAT  Hindi ka pa gaanong nilalagnat, sakit ay di pa...
# 4               SUNGOT             Maitim na puwit, tangkay ay nakakabit.
# ..                 ...                                                ...
# 488             JACKET  Hindi tao, hindi hayop, hindi apoy ngunit nagb...
# 489             JACKET  Hindi tao,  hindi hayop, pero bagay na sinusuo...
# 490  BAHAY NG KALAPATI                 Bahay ng aluwagi, iisa ang haligi.
# 491          SIGARILYO  Sinisindihan at pinagbabaga, kanser sa baga an...
# 492            SALAMIN   Tumingin ka sa akin, ang makikita mo’y ikaw din.
#
# [493 rows x 2 columns]
